# %% [markdown]
# This demo uses sklearn's Iris dataset with LightGBM for classification.

# %%
import json
import lightgbm as lgb
import pandas as pd
from sklearn.metrics import mean_squared_error
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.datasets import  make_classification

# %%
iris = load_iris()   # Load Iris dataset
data=iris.data
target = iris.target
X_train,X_test,y_train,y_test =train_test_split(data,target,test_size=0.2)
 
 
# Load your data
# print('Load data...')
# df_train = pd.read_csv('../regression/regression.train', header=None, sep='\t')
# df_test = pd.read_csv('../regression/regression.test', header=None, sep='\t')
#
# y_train = df_train[0].values
# y_test = df_test[0].values
# X_train = df_train.drop(0, axis=1).values
# X_test = df_test.drop(0, axis=1).values
 
# Create lgb Dataset format
lgb_train = lgb.Dataset(X_train, y_train) # Saving to binary speeds up loading
lgb_eval = lgb.Dataset(X_test, y_test, reference=lgb_train)  # Create validation data
 
# Parameters as dict
params = {
    'task': 'train',
    'boosting_type': 'gbdt',  # Boosting type
    'objective': 'regression', # Objective
    'metric': {'l2', 'auc'},  # Metric
    'num_leaves': 31,   # Num leaves
    'learning_rate': 0.05,  # Learning rate
    'feature_fraction': 0.9, # Feature fraction for tree
    'bagging_fraction': 0.8, # Bagging fraction
    'bagging_freq': 5,  # bagging every k iterations
    'verbose': 1 # Verbosity level
}
 
print('Start training...')
# 训练 cv and train
gbm = lgb.train(params,lgb_train,num_boost_round=20,valid_sets=lgb_eval,early_stopping_rounds=5) # Train with params and dataset
 
print('Save model...') 
 
gbm.save_model('model.txt')   # Save model after training
 
print('Start predicting...')
# Predict
y_pred = gbm.predict(X_test, num_iteration=gbm.best_iteration) # Use best_iteration if early stopping enabled
# Evaluate model
print('The rmse of prediction is:', mean_squared_error(y_test, y_pred) ** 0.5) # RMSE between true and predicted
# Out:
# Start training...
# [1]	valid_0's auc: 1	valid_0's l2: 0.625393
# Training until validation scores don't improve for 5 rounds.
# [2]	valid_0's auc: 1	valid_0's l2: 0.567814
# [3]	valid_0's auc: 1	valid_0's l2: 0.515827
# [4]	valid_0's auc: 1	valid_0's l2: 0.466764
# [5]	valid_0's auc: 1	valid_0's l2: 0.424377
# [6]	valid_0's auc: 1	valid_0's l2: 0.385323
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1	valid_0's l2: 0.625393
# Save model...
# Start predicting...
# The rmse of prediction is: 0.7908176179297906
